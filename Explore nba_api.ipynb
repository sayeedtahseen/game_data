# %%
# %pip install nba_api

# %%
import pandas as pd

# %%
from nba_api.stats.static import teams

# %%
type(teams)
# Out:
# module

# %% [markdown]
# Trying to find all methods associated to the module

# %%
dir(teams)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_find_team_by_abbreviation',
#  '_find_team_name_by_id',
#  '_find_teams',
#  '_find_teams_by_championship_year',
#  '_find_teams_by_year_founded',
#  '_get_team_dict',
#  '_get_teams',
#  'find_team_by_abbreviation',
#  'find_team_name_by_id',
#  'find_teams_by_championship_year',
#  'find_teams_by_city',
#  'find_teams_by_full_name',
#  'find_teams_by_nickname',
#  'find_teams_by_state',
#  'find_teams_by_year_founded',
#  'find_wnba_team_by_abbreviation',
#  'find_wnba_team_name_by_id',
#  'find_wnba_teams_by_championship_year',
#  'find_wnba_teams_by_city',
#  'find_wnba_teams_by_full_name',
#  'find_wnba_teams_by_nickname',
#  'find_wnba_teams_by_state',
#  'find_wnba_teams_by_year_founded',
#  'get_teams',
#  'get_wnba_teams',
#  're',
#  'team_index_abbreviation',
#  'team_index_championship_year',
#  'team_index_city',
#  'team_index_full_name',
#  'team_index_id',
#  'team_index_nickname',
#  'team_index_state',
#  'team_index_year_founded',
#  'teams',
#  'wnba_teams']

# %%
nba_teams = teams.get_teams()

# %% [markdown]
# Number of teams in the NBA

# %%
nba_teams[0]
len(nba_teams)
# Out:
# 30

# %% [markdown]
# Teams and their team id's, going to need this later to query all players from each team

# %%
for team in nba_teams:
    print(team['id'], team['abbreviation'])
# Out:
# 1610612737 ATL
# 1610612738 BOS
# 1610612739 CLE
# 1610612740 NOP
# 1610612741 CHI
# 1610612742 DAL
# 1610612743 DEN
# 1610612744 GSW
# 1610612745 HOU
# 1610612746 LAC
# 1610612747 LAL
# 1610612748 MIA
# 1610612749 MIL
# 1610612750 MIN
# 1610612751 BKN
# 1610612752 NYK
# 1610612753 ORL
# 1610612754 IND
# 1610612755 PHI
# 1610612756 PHX
# 1610612757 POR
# 1610612758 SAC
# 1610612759 SAS
# 1610612760 OKC
# 1610612761 TOR
# 1610612762 UTA
# 1610612763 MEM
# 1610612764 WAS
# 1610612765 DET
# 1610612766 CHA

# %% [markdown]
# Finding players - searching my team id

# %%
from nba_api.stats.endpoints import playerindex

# %%
players = playerindex.PlayerIndex(team_id_nullable='1610612757')

# %%
por_players = players.get_data_frames()[0]

# %%
por_players.head()
# Out:
#    PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME      PLAYER_SLUG TEAM_SLUG  \
# 0    1630166           Avdija              Deni      deni-avdija   blazers
# 1    1641739           Camara           Toumani   toumani-camara   blazers
# 2    1631321          Cissoko              Sidy     sidy-cissoko   blazers
# 3    1642270          Clingan           Donovan  donovan-clingan   blazers
# 4     203924            Grant            Jerami     jerami-grant   blazers
#
#       TEAM_ID TEAM_CITY      TEAM_NAME TEAM_ABBREVIATION JERSEY_NUMBER  ...  \
# 0  1610612757  Portland  Trail Blazers               POR             8  ...
# 1  1610612757  Portland  Trail Blazers               POR            33  ...
# 2  1610612757  Portland  Trail Blazers               POR            91  ...
# 3  1610612757  Portland  Trail Blazers               POR            23  ...
# 4  1610612757  Portland  Trail Blazers               POR             9  ...
#
#   DRAFT_YEAR DRAFT_ROUND DRAFT_NUMBER ROSTER_STATUS FROM_YEAR  TO_YEAR   PTS  \
# 0     2020.0         1.0          9.0           1.0      2020     2025  24.2
# 1     2023.0         2.0         52.0           1.0      2023     2025  13.4
# 2     2023.0         2.0         44.0           1.0      2023     2025   5.1
# 3     2024.0         1.0          7.0           1.0      2024     2025  12.1
# 4     2014.0         2.0         39.0           1.0      2014     2025  18.6
#
#     REB  AST STATS_TIMEFRAME
# 0   6.9  6.7          Season
# 1   5.1  2.5          Season
# 2   2.2  1.5          Season
# 3  11.6  2.1          Season
# 4   3.5  2.1          Season
#
# [5 rows x 25 columns]

# %%
por_players.sort_values('TO_YEAR', ascending=False)
# Out:
#     PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME          PLAYER_SLUG  \
# 0     1630166           Avdija              Deni          deni-avdija
# 1     1641739           Camara           Toumani       toumani-camara
# 16    1642905           Hansen              Yang          yang-hansen
# 15    1629057     Williams III            Robert  robert-williams-iii
# 14    1631104           Wesley             Blake         blake-wesley
# 13    1629680         Thybulle           Matisse     matisse-thybulle
# 12    1631101           Sharpe           Shaedon       shaedon-sharpe
# 11    1631200           Murray              Kris          kris-murray
# 10    1631126             Love             Caleb           caleb-love
# 9      203081          Lillard            Damian       damian-lillard
# 8     1630249           Krejčí               Vít           vít-krejčí
# 7     1643257             Kent            Jayson          jayson-kent
# 6      201950          Holiday              Jrue         jrue-holiday
# 5     1630703        Henderson             Scoot      scoot-henderson
# 4      203924            Grant            Jerami         jerami-grant
# 3     1642270          Clingan           Donovan      donovan-clingan
# 2     1631321          Cissoko              Sidy         sidy-cissoko
# 17    1642959       Youngblood             Chris     chris-youngblood
#
#    TEAM_SLUG     TEAM_ID TEAM_CITY      TEAM_NAME TEAM_ABBREVIATION  \
# 0    blazers  1610612757  Portland  Trail Blazers               POR
# 1    blazers  1610612757  Portland  Trail Blazers               POR
# 16   blazers  1610612757  Portland  Trail Blazers               POR
# 15   blazers  1610612757  Portland  Trail Blazers               POR
# 14   blazers  1610612757  Portland  Trail Blazers               POR
# 13   blazers  1610612757  Portland  Trail Blazers               POR
# 12   blazers  1610612757  Portland  Trail Blazers               POR
# 11   blazers  1610612757  Portland  Trail Blazers               POR
# 10   blazers  1610612757  Portland  Trail Blazers               POR
# 9    blazers  1610612757  Portland  Trail Blazers               POR
# 8    blazers  1610612757  Portland  Trail Blazers               POR
# 7    blazers  1610612757  Portland  Trail Blazers               POR
# 6    blazers  1610612757  Portland  Trail Blazers               POR
# 5    blazers  1610612757  Portland  Trail Blazers               POR
# 4    blazers  1610612757  Portland  Trail Blazers               POR
# 3    blazers  1610612757  Portland  Trail Blazers               POR
# 2    blazers  1610612757  Portland  Trail Blazers               POR
# 17   blazers  1610612757  Portland  Trail Blazers               POR
#
#    JERSEY_NUMBER  ... DRAFT_YEAR DRAFT_ROUND DRAFT_NUMBER ROSTER_STATUS  \
# 0              8  ...     2020.0         1.0          9.0           1.0
# 1             33  ...     2023.0         2.0         52.0           1.0
# 16            16  ...     2025.0         1.0         16.0           1.0
# 15            35  ...     2018.0         1.0         27.0           1.0
# 14             1  ...     2022.0         1.0         25.0           1.0
# 13             4  ...     2019.0         1.0         20.0           1.0
# 12            17  ...     2022.0         1.0          7.0           1.0
# 11            24  ...     2023.0         1.0         23.0           1.0
# 10             2  ...        NaN         NaN          NaN           1.0
# 9              0  ...     2012.0         1.0          6.0           1.0
# 8             27  ...     2020.0         2.0         37.0           1.0
# 7            NaN  ...        NaN         NaN          NaN           1.0
# 6              5  ...     2009.0         1.0         17.0           1.0
# 5             00  ...     2023.0         1.0          3.0           1.0
# 4              9  ...     2014.0         2.0         39.0           1.0
# 3             23  ...     2024.0         1.0          7.0           1.0
# 2             91  ...     2023.0         2.0         44.0           1.0
# 17             3  ...        NaN         NaN          NaN           1.0
#
#    FROM_YEAR  TO_YEAR   PTS   REB  AST STATS_TIMEFRAME
# 0       2020     2025  24.2   6.9  6.7          Season
# 1       2023     2025  13.4   5.1  2.5          Season
# 16      2025     2025   2.2   1.5  0.5          Season
# 15      2018     2025   6.7   7.0  1.0          Season
# 14      2022     2025   4.8   1.3  2.0          Season
# 13      2019     2025   5.8   2.0  0.9          Season
# 12      2022     2025  20.8   4.3  2.6          Season
# 11      2023     2025   5.8   3.6  1.4          Season
# 10      2025     2025  10.4   2.3  2.5          Season
# 9       2012     2025   NaN   NaN  NaN          Season
# 8       2021     2025   8.5   2.3  1.5          Season
# 7       2025     2025   2.0   1.0  0.0          Season
# 6       2009     2025  16.3   4.6  6.1          Season
# 5       2023     2025  14.2   2.7  3.7          Season
# 4       2014     2025  18.6   3.5  2.1          Season
# 3       2024     2025  12.1  11.6  2.1          Season
# 2       2023     2025   5.1   2.2  1.5          Season
# 17      2025     2025   2.1   0.8  0.4          Season
#
# [18 rows x 25 columns]

# %%
draft_2020 = playerindex.PlayerIndex(team_id_nullable='1610612757', draft_year_nullable='2020')

# %%
draft_2020.get_data_frames()[0]
# Out:
#    PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME  PLAYER_SLUG TEAM_SLUG  \
# 0    1630166           Avdija              Deni  deni-avdija   blazers
# 1    1630249           Krejčí               Vít   vít-krejčí   blazers
#
#       TEAM_ID TEAM_CITY      TEAM_NAME TEAM_ABBREVIATION JERSEY_NUMBER  ...  \
# 0  1610612757  Portland  Trail Blazers               POR             8  ...
# 1  1610612757  Portland  Trail Blazers               POR            27  ...
#
#   DRAFT_YEAR DRAFT_ROUND DRAFT_NUMBER ROSTER_STATUS FROM_YEAR  TO_YEAR   PTS  \
# 0       2020           1            9           1.0      2020     2025  24.2
# 1       2020           2           37           1.0      2021     2025   8.5
#
#    REB  AST STATS_TIMEFRAME
# 0  6.9  6.7          Season
# 1  2.3  1.5          Season
#
# [2 rows x 25 columns]

# %% [markdown]
# NOTE: not all columns are made equal, need to check using dtypes and potentially convert

# %%
por_players.DRAFT_YEAR = por_players.DRAFT_YEAR.astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 por_players.DRAFT_YEAR = por_players.DRAFT_YEAR.astype('int64')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:185, in astype_array(values, dtype, copy)
#     182     values = values.astype(dtype, copy=copy)
#     184 else:
# --> 185     values = _astype_nansafe(values, dtype, copy=copy)
#     187 # in pandas we don't store numpy str dtypes, so convert to object
#     188 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:102, in _astype_nansafe(arr, dtype, copy, skipna)
#      97     return lib.ensure_string_array(
#      98         arr, skipna=skipna, convert_na_value=False
#      99     ).reshape(shape)
#     101 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 102     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     104 elif arr.dtype == object:
#     105     # if we have a datetime/timedelta array of objects
#     106     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     108     if lib.is_np_dtype(dtype, "M"):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:146, in _astype_float_to_int_nansafe(values, dtype, copy)
#     142 """
#     143 astype with a check preventing converting NaN to a meaningless integer value.
#     144 """
#     145 if not np.isfinite(values).all():
# --> 146     raise IntCastingNaNError(
#     147         "Cannot convert non-finite values (NA or inf) to integer."
#     148         "Replace or remove non-finite values or cast to an integer type"
#     149         "that supports these values (e.g. 'Int64')"
#     150     )
#     151 if dtype.kind == "u":
#     152     # GH#45151
#     153     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer.Replace or remove non-finite values or cast to an integer typethat supports these values (e.g. 'Int64')

# %%
por_players.dtypes

# %% [markdown]
# Trying to find player stats

# %%
from nba_api.stats.endpoints import playerdashboardbylastngames

# %%
player_stats = playerdashboardbylastngames.PlayerDashboardByLastNGames(player_id='1629057', last_n_games=20)

# %%
player_stats.get_data_frames()[0]

# %%
dir(players)

# %% [markdown]
# Finding players and player ids from players directory

# %%
from nba_api.stats.static import players

# %%
dir(players)

# %%
players.find_players_by_first_name('lebron')

# %% [markdown]
# Trying to query for one player to retrieve stats

# %%
from nba_api.stats.endpoints import playerdashboardbyteamperformance

# %%
james = playerdashboardbyteamperformance.PlayerDashboardByTeamPerformance(player_id='2544')

# %%
frames = james.get_data_frames()

# %%
frames[1]

# %% [markdown]
# Lots of this data does not make sense (to me)

# %%
frames[0]

# %%
from nba_api.stats.endpoints import playercareerstats

# %%
player_stats = playercareerstats.PlayerCareerStats(player_id='2544')

# %%
player_stats.get_json()

# %%
stats = player_stats.get_data_frames()[4]

# %%
stats

# %% [markdown]
# NOTE: this is the API to use, to retrieve game data for each player

# %%
from nba_api.stats.endpoints import playergamelog

# %%
current_gamelog = playergamelog.PlayerGameLog(player_id='2544')

# %%
logs = current_gamelog.get_data_frames()[0]

# %%
logs.head()

# %%
logs.dtypes
